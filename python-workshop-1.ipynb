# %% [markdown]
# # Compneuro.neuromatch
#
# https://compneuro.neuromatch.io/tutorials/W0D1_PythonWorkshop1/student/W0D1_Tutorial1.html#video-8-nano-recap-of-ensemble-statistics-lists

# %% [markdown]
# # Coding Exercise 1: Defining parameters
#
# ```python
# # t_max = 150e-3   # second
# # dt = 1e-3        # second
# # tau = 20e-3      # second
# # el = -60e-3      # milivolt
# # vr = -70e-3      # milivolt
# # vth = -50e-3     # milivolt
# # r = 100e6        # ohm
# # i_mean = 25e-11  # ampere
#
# # print(t_max, dt, tau, el, vr, vth, r, i_mean)
# ```

# %%
t_max = 150e-3   # second
dt = 1e-3        # second
tau = 20e-3      # second
el = -60e-3      # milivolt
vr = -70e-3      # milivolt
vth = -50e-3     # milivolt
r = 100e6        # ohm
i_mean = 25e-11  # ampere

print(t_max, dt, tau, el, vr, vth, r, i_mean)
# Out:
# 0.15 0.001 0.02 -0.06 -0.07 -0.05 100000000.0 2.5e-10

# %% [markdown]
# # Coding Exercise 2: Simulating an input current
#
# ```python range(start, stop, step)```
#
# Parameters:
# - start: Optional. An integer number specifying at which position to start. Default is 0
# - stop: Required. An integer number specifying at which position to stop (not included).
# - step: Optional. An integer number specifying the incrementation. Default is 1
# ```python
# # Loop for 10 steps, variable 'step' takes values from 0 to 9
# for step in range(10):
#
#   # Compute value of t
#   t = step * dt
#
#   # Compute value of i at this time step
#   i = ...
#
#   # Print value of i
#   print(i)
#   ```

# %%
import numpy as np

# Loop for 10 steps, variable 'step' takes values from 0 to 9
for step in range(10):

  # Compute value of t
  t = step * dt

  # Compute value of i at this time step
  i = i_mean * (1 + np.sin((2 * np.pi * t) / 0.01))

  # Print value of i
  print(i)
# Out:
# 2.5e-10
# 3.969463130731183e-10
# 4.877641290737885e-10
# 4.877641290737885e-10
# 3.9694631307311837e-10
# 2.5000000000000007e-10
# 1.0305368692688176e-10
# 1.2235870926211617e-11
# 1.223587092621159e-11
# 1.0305368692688186e-10

# %% [markdown]
# # Section 1.4: Print formatting

# %%
x = 3.14159265e-1
print(f'{x:.3f}')

print(f'{x:.4e}')
# Out:
# 0.314
# 3.1416e-01

# %% [markdown]
# Repeat the loop from the previous exercise and print the 't' values with three decimal points, and synaptic input I(t) with four decimal points in exponential notation.
# ```python
# # Initialize step_end
# step_end = 10
#
# # Loop for step_end steps
# for step in range(step_end):
#
#   # Compute value of t
#   t = step * dt
#
#   # Compute value of i at this time step
#   i = i_mean * (1 + np.sin((t * 2 * np.pi) / 0.01))
#
#   # Print value of t and i
#   print(...)
#   ```

# %%
# Initialize step_end
step_end = 10

# Loop for step_end steps
for step in range(step_end):

  # Compute value of t
  t = step * dt

  # Compute value of i at this time step
  i = i_mean * (1 + np.sin((t * 2 * np.pi) / 0.01))

  # Print value of t and i
  print(f'{t:.3f} {i:.4e}')
# Out:
# 0.000 2.5000e-10
# 0.001 3.9695e-10
# 0.002 4.8776e-10
# 0.003 4.8776e-10
# 0.004 3.9695e-10
# 0.005 2.5000e-10
# 0.006 1.0305e-10
# 0.007 1.2236e-11
# 0.008 1.2236e-11
# 0.009 1.0305e-10

# %% [markdown]
# # Section : For loops & discrete time integration
#
# ## Section 2.1: For Loops
# ```python
# for step in [0, 1, 2]:
#   print(step)
#
# for step in range(3):
#   print(step)
#
# start = 0
# end = 3
# stepsize = 1
#
# for step in range(start, end, stepsize):
#   print(step)
# ```
# ## Section 2.2: Discrete time integration with spikes
# ### Coding exercise 4: Simulating membrane potential
# ```python
# #################################################
# ## TODO for students: fill out compute v code ##
# # Fill out code and comment or remove the next line
# raise NotImplementedError("Student exercise: You need to fill out code to compute v")
# #################################################
#
# # Initialize step_end and v0
# step_end = 10
# v = el
#
# # Loop for step_end steps
# for step in range(step_end):
#   # Compute value of t
#   t = step * dt
#
#   # Compute value of i at this time step
#   i = i_mean * (1 + np.sin((t * 2 * np.pi) / 0.01))
#
#   # Compute v
#   v = ...
#
#   # Print value of t and v
#   print(f"{t:.3f} {v:.4e}")
#   ```

# %%
#################################################
## TODO for students: fill out compute v code ##
# Fill out code and comment or remove the next line
#raise NotImplementedError("Student exercise: You need to fill out code to compute v")
#################################################

# Initialize step_end and v0
step_end = 10
v = el

# Loop for step_end steps
for step in range(step_end):
  # Compute value of t
  t = step * dt

  # Compute value of i at this time step
  i = i_mean * (1 + np.sin((t * 2 * np.pi) / 0.01))

  # Compute v
  v = v + (dt / tau) * (el -v + r * i)

  # Print value of t and v
  print(f"{t:.3f} {v:.4e}")
# Out:
# 0.000 -5.8750e-02
# 0.001 -5.6828e-02
# 0.002 -5.4548e-02
# 0.003 -5.2381e-02
# 0.004 -5.0778e-02
# 0.005 -4.9989e-02
# 0.006 -4.9974e-02
# 0.007 -5.0414e-02
# 0.008 -5.0832e-02
# 0.009 -5.0775e-02

# %% [markdown]
# # Section 3: Plotting
#
# uses package matplotlib

# %%
import matplotlib.pyplot as plt

#################################################
## TODO for students: fill out the figure initialization and plotting code below ##
# Fill out code and comment or remove the next line
# raise NotImplementedError("Student exercise: You need to fill out current figure code")
#################################################

# Initialize step_end
step_end = 25

# Initialize the figure
plt.figure()
plt.title('Synaptic Input $I(t)$')
plt.xlabel('time (s)')
plt.ylabel('$I$ (A)')
plt.legend()

# Loop for step_end steps
for step in range(step_end):

  # Compute value of t
  t = step * dt

  # Compute value of i at this time step
  i = i_mean * (1 + np.sin((t * 2 * np.pi) / 0.01))

  # Plot i (use 'ko' to get small black dots (short for color='k' and marker = 'o'))
  plt.plot(t, i, 'ko')

# Display the plot
plt.show()
# Out:
# /var/folders/_k/b3pgxxcs1zx7vqbvqh97qgw40000gn/T/ipykernel_76854/1694003165.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#################################################
## TODO for students: fill out the figure initialization and plotting code below ##
# Fill out code and comment or remove the next line
#raise NotImplementedError("Student exercise: You need to fill out membrane potential figure code")
#################################################

# Initialize step_end
step_end = int(t_max / dt)

# Initialize v0
v = el

# Initialize the figure
plt.figure()
plt.title('$V_m$ with sinusoidal $I$(t)')
plt.xlabel('time (s)')
plt.ylabel('$V_m$ (V)');

# Loop for step_end steps
for step in range(step_end):

  # Compute value of t
  t = step * dt

  # Compute value of i at this time step
  i = i_mean * (1 + np.sin((t * 2 * np.pi) / 0.01))

  # Compute v
  v = v + dt/tau * (el - v + r*i)

  # Plot v (using 'k.' to get even smaller markers)
  plt.plot(t, v, 'k.')

# Display plot
plt.show()

# %% [markdown]
# # Section 4: Random synaptic input
# Adding randomness

# %%
#################################################
## TODO for students: fill out code to get random input ##
# Fill out code and comment or remove the next line
#raise NotImplementedError("Student exercise: You need to fill out random input code")
#################################################

# Set random number generator
np.random.seed(2020)

# Initialize step_end and v
step_end = int(t_max / dt)
v = el

# Initialize the figure
plt.figure()
plt.title('$V_m$ with random I(t)')
plt.xlabel('time (s)')
plt.ylabel('$V_m$ (V)')
plt.legend()

# loop for step_end steps
for step in range(step_end):

  # Compute value of t
  t = step * dt

  # Get random number in correct range of -1 to 1 (will need to adjust output of np.random.random)
  random_num = 2 * np.random.random() - 1

  # Compute value of i at this time step
  i = i_mean * (1 + 0.1 * random_num * ((t_max / dt) ** 0.5))

  # Compute v
  v = v + dt/tau * (el - v + r*i)

  # Plot v (using 'k.' to get even smaller markers)
  plt.plot(t, v, 'k.', label = 'dot')


# Display plot
plt.show()
# Out:
# /var/folders/_k/b3pgxxcs1zx7vqbvqh97qgw40000gn/T/ipykernel_76854/1358846134.py:19: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Section 5: Lists & ensemble statistics

# %%
my_list = ["Lihua", 100, 0.5+0.5j]
print(my_list)

my_list.append(10.0)
print(my_list)

my_list.insert(0, "Zhang") # 0 in the index for insert
print(my_list)

my_list = my_list + [10.0, 20.0]
print(my_list)

my_list = ["x", "y", "z"] + my_list
print(my_list)

my_list.extend(["a", "b", "c"])  # extend adds multiple elements
print(my_list)

print(my_list[0])  # Access first element
print(my_list[1])  # Access second element
print(my_list[-1])  # Access last element
print(my_list[-2])  # Access second to last element
print(my_list[1:4])  # Access elements from index 1 to 3 (4 is exclusive)
print(my_list[1:])  # Access elements from index 1 to the end
print(my_list[:3])  # Access first three elements
print(my_list[1:4:2])  # Access elements from index 1 to 3 with a step of 2
print(my_list[::2])  # Access every second element
print(my_list[::-1])  # Access elements in reverse order
# Out:
# ['Lihua', 100, (0.5+0.5j)]
# ['Lihua', 100, (0.5+0.5j), 10.0]
# ['Zhang', 'Lihua', 100, (0.5+0.5j), 10.0]
# ['Zhang', 'Lihua', 100, (0.5+0.5j), 10.0, 10.0, 20.0]
# ['x', 'y', 'z', 'Zhang', 'Lihua', 100, (0.5+0.5j), 10.0, 10.0, 20.0]
# ['x', 'y', 'z', 'Zhang', 'Lihua', 100, (0.5+0.5j), 10.0, 10.0, 20.0, 'a', 'b', 'c']
# x
# y
# c
# b
# ['y', 'z', 'Zhang']
# ['y', 'z', 'Zhang', 'Lihua', 100, (0.5+0.5j), 10.0, 10.0, 20.0, 'a', 'b', 'c']
# ['x', 'y', 'z']
# ['y', 'Zhang']
# ['x', 'z', 'Lihua', (0.5+0.5j), 10.0, 'a', 'c']
# ['c', 'b', 'a', 20.0, 10.0, 10.0, (0.5+0.5j), 100, 'Lihua', 'Zhang', 'z', 'y', 'x']

# %% [markdown]
# Enumerate

# %%
my_list = ['pyramidal', 'inhibitory', 'glial']
for idx, item in enumerate(my_list): # enumerate gives index and item
    print(f"Item {idx}: {item}")
# Out:
# Item 0: pyramidal
# Item 1: inhibitory
# Item 2: glial

# %% [markdown]
# List Comprehension

# %%
squares = [x**2 for x in range(10)]  # List comprehension to create a list of squares
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# Plotting lists

# %%
x = [0, 1, 2, 3, 4, 5]
plt.plot(x, x, 'ro')  # Plot x vs x with red circles

# %% [markdown]
# Ensemble statistics

# %%
my_list = [1] + [1]
print(my_list)  # Output: [1, 1]

my_list = 3 * [1]
print(my_list)  # Output: [1, 1, 1]

my_list = [100, 'lihua', 10., 1e4]
print(my_list[0])  # Output: 100
print(my_list[-1])  # Output: 10000.0 (1e4 is 10000.0)
print(my_list[1:3])

x = [0, 1, 2, 3, 4, 5, 6]
print(x[::2])  # Output: [100, 10.0] (every second element)
plt.plot(x, x, 'ro')
# Out:
# [1, 1]
# [1, 1, 1]
# 100
# 10000.0
# ['lihua', 10.0]
# [0, 2, 4, 6]

# %% [markdown]
# ## Coding Exercise 8: Storing simulations in lists

# %%
#################################################
## TODO for students: fill out code to store v in list ##
# Fill out code and comment or remove the next line
# raise NotImplementedError("Student exercise: You need to store v in list")
#################################################

# Set random number generator
np.random.seed(2020)

# Initialize step_end and n
step_end = int(t_max / dt) 
n = 50

# Intiatialize the list v_n with 50 values of membrane leak potential el
v_n = [el] * n
print(v_n)

# Initialize the figure
plt.figure()
plt.title('Multiple realizations of $V_m$')
plt.xlabel('time (s)')
plt.ylabel('$V_m$ (V)')

# Loop for step_end steps
for step in range(step_end):
  # Compute value of t
  t = step * dt

  # Loop for n simulations
  for j in range(0, n):

    # Compute value of i at this time step
    i = i_mean * (1 + 0.1 * (t_max/dt)**(0.5) * (2* np.random.random() - 1))

    # Compute value of v for this simulation
    v_n[j] = v_n[j] + (dt / tau) * (el - v_n[j] + r * i)

  # Compute sample mean by summing list of v_n using sum, and dividing by n
  v_mean = sum(v_n) / n

  # Initialize a list `v_var_n` with the contribution of each V_n(t) to
  # Var(t) with a list comprehension over values of v_n
  v_var_n = [(v_n[j] - v_mean) ** 2 for j in range(n)]

  # Compute sample variance v_var by summing the values of v_var_n with sum and dividing by n-1
  v_var = sum(v_var_n) / (n - 1)

  # Compute the standard deviation v_std with the function np.sqrt
  v_std = np.sqrt(v_var)

  # Plot all simulations (use alpha = 0.1 to make each marker slightly transparent)
  plt.plot([t] * n, v_n, 'k.', alpha=0.1)

  # Plot sample mean using alpha=0.8 and'C0.' for blue
  plt.plot(t, v_mean, 'C0.', alpha=0.8, markersize = 10)

  # Plot mean + standard deviation with alpha=0.8 and argument 'C7.'
  plt.plot([t] * n, [v_mean + v_std] * n, 'C7.', alpha=0.8)

  # Plot mean - standard deviation with alpha=0.8 and argument 'C7.'
  plt.plot([t] * n, [v_mean - v_std] * n, 'C7.', alpha=0.8)

# Display plot
plt.show()
# Out:
# [-0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06, -0.06]

# %% [markdown]
# # Section 6: Using NumPy

# %%
a = np.array([1, 2, 3])
print(a)
print(a.shape)

a = np.array([[1, 2, 3],
              [4, 5, 6]])
print(a)
print(a.shape)

print(a + 1)
print(a * 3)
print(a ** 2)
# Out:
# [1 2 3]
# (3,)
# [[1 2 3]
#  [4 5 6]]
# (2, 3)
# [[2 3 4]
#  [5 6 7]]
# [[ 3  6  9]
#  [12 15 18]]
# [[ 1  4  9]
#  [16 25 36]]

# %%
#################################################
## TODO for students: fill out code to rewrite simulation in numpy##
# Fill out code and comment or remove the next line
# raise NotImplementedError("Student exercise: You need to rewrite simulation in numpy")
#################################################

import numpy as np

# Set parameters
t_max = 150e-3   # second
dt = 1e-3        # second
tau = 20e-3      # second
el = -60e-3      # milivolt
vr = -70e-3      # milivolt
vth = -50e-3     # milivolt
r = 100e6        # ohm
i_mean = 25e-11  # ampere

#print(t_max, dt, tau, el, vr, vth, r, i_mean)

# Set random number generator
np.random.seed(2020)

# Initialize step_end, t_range, v
step_end = int(t_max / dt) - 1
t_range = np.linspace(0, t_max, num=step_end, endpoint=False)
#print(t_range)
v = el * np.ones(step_end)
#print(v)
# Simulate current over time
i = i_mean * (1 + 0.1 * (t_max/dt)**(0.5) * (2* np.random.random(step_end) - 1))
#print(i)

# Loop for step_end steps
for step in range(1, step_end):

  # Compute v as function of i
  v[step] = v[step - 1] + (dt / tau) * (el - v[step - 1] + r * i[step])


# Plot membrane potential
plt.figure()
plt.title('$V_m$ with random I(t)')
plt.xlabel('time (s)')
plt.ylabel('$V_m$ (V)')

plt.plot(t_range, v, 'k.')
plt.show()

# %%
#################################################
## TODO for students: fill out code to rewrite simulation in numpy##
# Fill out code and comment or remove the next line
# raise NotImplementedError("Student exercise: You need to rewrite simulation in numpy")
#################################################

import numpy as np

# Set parameters
t_max = 150e-3   # second
dt = 1e-3        # second
tau = 20e-3      # second
el = -60e-3      # milivolt
vr = -70e-3      # milivolt
vth = -50e-3     # milivolt
r = 100e6        # ohm
i_mean = 25e-11  # ampere

# Set random number generator
np.random.seed(2020)

# Initialize step_end, t_range, v
step_end = int(t_max / dt) - 1
t_range = np.linspace(0, t_max, num=step_end, endpoint=False)
v = el * np.ones(step_end)

# Simulate current over time
i = i_mean * (1 + 0.1 * (t_max/dt) ** (0.5) * (2 * np.random.random(step_end) - 1))

# Loop for step_end values of i using enumerate
for step, i_step in enumerate(i):

  # Skip first iteration
  if step==0:
    continue

  # Compute v as function of i using i_step
  v[step] = v[step - 1] + (dt / tau) * (el - v[step - 1] + r * i_step)

# Plot figure
plt.figure()
plt.title('$V_m$ with random I(t)')
plt.xlabel('time (s)')
plt.ylabel('$V_m$ (V)')

plt.plot(t_range, v, 'k')
plt.show()

# %% [markdown]
# # Section 7: Aggregation

# %%
a = np.array([[1, 2, 3],
             [4, 5, 6]])

np.sum(a, axis=0)  # Sum over columns
np.sum(a, axis=1)  # Sum over rows

np.prod(a, axis=0)  # Product over columns
np.prod(a, axis=1)  # Product over rows

np.mean(a, axis=0)  # Mean over columns
np.mean(a, axis=1)  # Mean over rows

np.std(a, axis=0)  # Standard deviation over columns
np.std(a, axis=1)  # Standard deviation over rows

np.var(a, axis=0)  # Variance over columns
np.var(a, axis=1)  # Variance over rows

np.min(a, axis=0)  # Minimum over columns
np.min(a, axis=1)  # Minimum over rows

np.max(a, axis=0)  # Maximum over columns
np.max(a, axis=1)  # Maximum over rows

a = np.array([1, 2, 3])
b = np.array([[4, 5, 6]])
print(a, a.shape)  # Output: (3,)
print(b, b.shape)  # Output: (1, 3)
# Out:
# [1 2 3] (3,)
# [[4 5 6]] (1, 3)

# %% [markdown]
# ## Coding Exercise 13: Using 2D arrays

# %%
#################################################
## TODO for students: fill out code to use 2d arrays ##
# Fill out code and comment or remove the next line
# raise NotImplementedError("Student exercise: You need to rewrite code to use 2d arrays")
#################################################

# Set random number generator
np.random.seed(2020)

# Initialize step_end, n, t_range, v and i
step_end = int(t_max / dt)
n = 50
t_range = np.linspace(0, t_max, num=step_end)
v_n = el * np.ones([n, step_end])
# print(v_n, v_n.shape)
i = i_mean * (1 + 0.1 * (t_max/dt) ** (0.5) * (2 * np.random.random([n, step_end]) - 1))

# Loop for step_end - 1 steps
for step in range(1, step_end):
   # Compute v_n
   v_n[:, step] = v_n[:, step - 1] + (dt / tau) * (el - v_n[:, step - 1] + r * i[:, step])

# Compute sample mean (use np.mean)
v_mean = np.mean(v_n, axis=0)

# Compute sample standard deviation (use np.std)
v_std = np.std(v_n, axis=0)

# Plot figure
plt.figure()
plt.title('Multiple realizations of $V_m$')
plt.xlabel('time (s)')
plt.ylabel('$V_m$ (V)')

plt.plot(t_range, v_n.T, 'k', alpha=0.3)  # Transpose v_n to match t_range shape

plt.plot(t_range, v_n[-1], 'k.', alpha=0.3, label='V(t)')
plt.plot(t_range, v_mean, 'C0', alpha=0.8, label='mean')
plt.plot(t_range, v_mean+v_std, 'C1', alpha=0.8)
plt.plot(t_range, v_mean-v_std, 'C1', alpha=0.8, label='mean $\pm$ std')

plt.legend()
plt.show()
# Out:
# <>:40: SyntaxWarning: invalid escape sequence '\p'
# <>:40: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/_k/b3pgxxcs1zx7vqbvqh97qgw40000gn/T/ipykernel_76854/3113133724.py:40: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(t_range, v_mean-v_std, 'C1', alpha=0.8, label='mean $\pm$ std')
